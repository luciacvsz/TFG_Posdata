# %% [markdown]
# # Test cases for posdata-deactivateuser-lambda

# %% [markdown]
# ### TC_00_SuccessfulUserDeactivation
#
# **Description:** Given an event with a valid request body (JSON string), when the lambda is invoked, then it returns HTTP `200` and the response body contains `user_id`.

# %% [markdown]
# **Input:**

# %%
{
    "body": {
        "user_id": "0f3a605fe48e4172ba48ed42290f19ef"
    }
}

# %% [markdown]
# **Output:**

# %% [markdown]
# {
#   "statusCode": 200,
#   "body": "{\"user_id\": \"0f3a605fe48e4172ba48ed42290f19ef\"}"
# }
