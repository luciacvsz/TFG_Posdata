# %% [markdown]
# # Test cases for posdata-createuser-lambda

# %% [markdown]
# ### TC_00_SuccessfulUserCreation
#
# **Description:** Given an event with a valid request body (JSON string), when the lambda is invoked, then it returns HTTP `201` and the response body contains `user_id`.

# %% [markdown]
# **Input:**

# %%
{
    "body": {
        "full_name": "Lucia Cuevas Sanchez",
        "contact": {
            "phone_number": "+34622807591",
            "email": "lcueva02@ucm.es"
        } ,
        "preferences": {
            "font_size": "regular",
            "notification_sound": "on",
            "color_scheme": "protanopia",
            "exhaustivity": "enhanced",
            "explanation_mode": "off"
        } ,
        "emergency_contacts": {
            "phone_numbers": "NONE",
            "emails": "NONE"
        }
    }
}

# %% [markdown]
# **Output:**

# %%
{
  "statusCode": 201,
  "body": "{\"user_id\": \"0f3a605fe48e4172ba48ed42290f19ef\"}"
}
